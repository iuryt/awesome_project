# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install cartopy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 65.5 MB/s eta 0:00:00
# ...

# %%
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
ls
# Out:
# drive/  sample_data/

# %%
fnames = glob("drive/MyDrive/workspace/awesome_project/data/*.dat")
data = []
for fname in fnames:
  datai = pd.read_csv(fname,names=["latitude","longitude","color","number"])
  datai["username"] = fname.split("/")[-1].split(".")[0]
  if datai.shape[0]==1:
    data.append(datai)
data = pd.concat(data)
data
# Out:
#     latitude   longitude      color  number             username
# 0 -12.114710  -77.011673       blue     7.0           DangoMelon
# 0  37.605534  -97.322205                NaN            Jocelyn79
# 0  40.353291   18.174009        red     5.0                Lecce
# 0  48.424340   11.757330     yellow     6.0    RQuilestinoOlario
# 0 -22.224500  166.517790       Blue     9.0  RomainIfremerNewCal
# 0 -23.758280  -45.413490       blue    10.0              agatapb
# 0  45.440845   12.315515        red     1.0            alexgag11
# 0  47.606209 -122.332069      green     3.0              cohenjt
# 0  35.179554  129.075638       pink     5.0              eunbcho
# 0  35.107322  129.091345       pink     5.0   eunbyeolcho-silver
# 0   1.344763  103.823671      green     4.0           joelwong17
# 0  54.092442   12.099147      green     8.0             ksenisaf
# 0  33.900000   18.400000       blue     9.0           mattcarr03
# ...

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.Robinson())

ax.set_global()

ax.stock_img()

ax.scatter(
    data.longitude,data.latitude,
    color="red",
    transform=ccrs.PlateCarree())

# %%
data.number.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.color.value_counts().plot(kind = "bar")
# Out:
# <Axes: >
